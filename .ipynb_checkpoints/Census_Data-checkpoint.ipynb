# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#save acs2017_census_tract_data to dataframe

ctdata = "acs2017_census_tract_data.csv"

ctdata_df = pd.read_csv("Resources/acs2017_census_tract_data.csv")
ctdata_df.head()
# Out:
#       TractId    State          County  TotalPop   Men  Women  Hispanic  \
# 0  1001020100  Alabama  Autauga County      1845   899    946       2.4
# 1  1001020200  Alabama  Autauga County      2172  1167   1005       1.1
# 2  1001020300  Alabama  Autauga County      3385  1533   1852       8.0
# 3  1001020400  Alabama  Autauga County      4267  2001   2266       9.6
# 4  1001020500  Alabama  Autauga County      9965  5054   4911       0.9
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   86.3    5.2     0.0  ...   0.5          0.0         2.1         24.5
# 1   41.6   54.5     0.0  ...   0.0          0.5         0.0         22.2
# 2   61.4   26.5     0.6  ...   1.0          0.8         1.5         23.1
# 3   80.3    7.1     0.5  ...   1.5          2.9         2.1         25.9
# 4   77.5   16.4     0.0  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
# get column names
    
list(ctdata_df.columns.values.tolist())
# Out:
# ['TractId',
#  'State',
#  'County',
#  'TotalPop',
#  'Men',
#  'Women',
#  'Hispanic',
#  'White',
#  'Black',
#  'Native',
#  'Asian',
#  'Pacific',
#  'VotingAgeCitizen',
#  'Income',
#  'IncomeErr',
#  'IncomePerCap',
#  'IncomePerCapErr',
#  'Poverty',
#  'ChildPoverty',
#  'Professional',
#  'Service',
#  'Office',
#  'Construction',
#  'Production',
#  'Drive',
#  'Carpool',
#  'Transit',
#  'Walk',
#  'OtherTransp',
#  'WorkAtHome',
#  'MeanCommute',
#  'Employed',
#  'PrivateWork',
#  'PublicWork',
#  'SelfEmployed',
#  'FamilyWork',
#  'Unemployment']

# %%
ctdata_df.describe()
# Out:
#             TractId      TotalPop           Men         Women      Hispanic  \
# count  7.400100e+04  74001.000000  74001.000000  74001.000000  73305.000000
# mean   2.839113e+10   4384.716017   2157.710707   2227.005311     17.265444
# std    1.647593e+10   2228.936729   1120.560504   1146.240218     23.073811
# min    1.001020e+09      0.000000      0.000000      0.000000      0.000000
# 25%    1.303901e+10   2903.000000   1416.000000   1465.000000      2.600000
# 50%    2.804700e+10   4105.000000   2007.000000   2082.000000      7.400000
# 75%    4.200341e+10   5506.000000   2707.000000   2803.000000     21.100000
# max    7.215375e+10  65528.000000  32266.000000  33262.000000    100.000000
#
#               White        Black        Native         Asian       Pacific  \
# count  73305.000000  73305.00000  73305.000000  73305.000000  73305.000000
# mean      61.309043     13.28910      0.734047      4.753691      0.147341
# ...

# %%
# create new dataframe with selected columns from ERD
new_ctdata_df = ctdata_df[['State', 'County','TotalPop','Men','Women','Hispanic','White', 'Black','Native','Asian','Pacific','Income','IncomePerCap','Poverty','ChildPoverty','PrivateWork','PublicWork','SelfEmployed','FamilyWork','Unemployment']].copy()
new_ctdata_df.head()
# Out:
#      State          County  TotalPop   Men  Women  Hispanic  White  Black  \
# 0  Alabama  Autauga County      1845   899    946       2.4   86.3    5.2
# 1  Alabama  Autauga County      2172  1167   1005       1.1   41.6   54.5
# 2  Alabama  Autauga County      3385  1533   1852       8.0   61.4   26.5
# 3  Alabama  Autauga County      4267  2001   2266       9.6   80.3    7.1
# 4  Alabama  Autauga County      9965  5054   4911       0.9   77.5   16.4
#
#    Native  Asian  Pacific   Income  IncomePerCap  Poverty  ChildPoverty  \
# 0     0.0    1.2      0.0  67826.0       33018.0     10.7          20.8
# 1     0.0    1.0      0.0  41287.0       18996.0     22.4          35.8
# 2     0.6    0.7      0.4  46806.0       21236.0     14.7          21.1
# 3     0.5    0.2      0.0  55895.0       28068.0      2.3           1.7
# 4     0.0    3.1      0.0  68143.0       36905.0     12.2          17.9
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
len(new_ctdata_df)
# Out:
# 74001

# %%
new_ctdata_df.describe()
# Out:
#                 Men         Women      Hispanic         White        Black  \
# count  74001.000000  74001.000000  73305.000000  73305.000000  73305.00000
# mean    2157.710707   2227.005311     17.265444     61.309043     13.28910
# std     1120.560504   1146.240218     23.073811     30.634461     21.60118
# min        0.000000      0.000000      0.000000      0.000000      0.00000
# 25%     1416.000000   1465.000000      2.600000     38.000000      0.80000
# 50%     2007.000000   2082.000000      7.400000     70.400000      3.80000
# 75%     2707.000000   2803.000000     21.100000     87.700000     14.60000
# max    32266.000000  33262.000000    100.000000    100.000000    100.00000
#
#              Native         Asian       Pacific         Income   IncomePerCap  \
# count  73305.000000  73305.000000  73305.000000   72885.000000   73256.000000
# mean       0.734047      4.753691      0.147341   61086.829265   30651.804194
# ...

# %%
new_ctdata_df.groupby(['State'])

# %%
new_ctdata_df.State
# Out:
# 0            Alabama
# 1            Alabama
# 2            Alabama
# 3            Alabama
# 4            Alabama
#             ...
# 73996    Puerto Rico
# 73997    Puerto Rico
# 73998    Puerto Rico
# 73999    Puerto Rico
# 74000    Puerto Rico
# Name: State, Length: 74001, dtype: object

# %%
new_ctdata_df['State'].valuecount
# Out:
# 0            Alabama
# 1            Alabama
# 2            Alabama
# 3            Alabama
# 4            Alabama
#             ...
# 73996    Puerto Rico
# 73997    Puerto Rico
# 73998    Puerto Rico
# 73999    Puerto Rico
# 74000    Puerto Rico
# Name: State, Length: 74001, dtype: object

# %%
new_ctdata_df.State.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
new_ctdata_df.drop_duplicates(subset=['Puerto Rico'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ff4be545b74f> in <module>
# ----> 1 new_ctdata_df.drop_duplicates(subset=['Puerto Rico'])
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# ...

# %%
 len(new_ctdata_df.columns)
# Out:
# 19

# %%
#create engine and connection to database

# %%
#verify table

# %%
#Load csv into database

# %%
#confirm data - query table
